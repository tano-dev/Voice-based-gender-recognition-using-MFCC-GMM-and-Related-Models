# %%
# Init data
import sys
sys.path.append("C:/Users/ADMIN/Documents/Voice-based-gender-recognition-using-MFCC-and-GMM/")
from Modules.DataProcessor import DataManager

# Data manager
data_manager = DataManager("SLR45.tgz")
data_manager.manage()
